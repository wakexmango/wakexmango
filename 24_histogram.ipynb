# %% [markdown]
# # 히스토그램

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/data/data.xlsx')
df.head(5)
# Out:
#    product_id product_type  ...              state    country
# 0           1        Shirt  ...  Western Australia  Australia
# 1           1        Shirt  ...  Western Australia  Australia
# 2           1        Shirt  ...           Tasmania  Australia
# 3           1        Shirt  ...         Queensland  Australia
# 4           1        Shirt  ...    South Australia  Australia
#
# [5 rows x 25 columns]

# %%
df['age'].describe()
# Out:
# count    5000.000000
# mean       48.760400
# std        17.577519
# min        20.000000
# 25%        34.000000
# 50%        48.000000
# 75%        63.000000
# max        80.000000
# Name: age, dtype: float64

# %%
df[df['age'] == 80]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 8))
plt.hist(df['age'])
# Out:
# (array([588., 461., 522., 513., 507., 451., 564., 428., 427., 539.]),
#  array([20., 26., 32., 38., 44., 50., 56., 62., 68., 74., 80.]),
#  <a list of 10 Patch objects>)

# %%
tb = pd.DataFrame([[20., 26., 32., 38., 44., 50., 56., 62., 68., 74., 80.],
                    [588., 461., 522., 513., 507., 451., 564., 428., 427., 539.]]).T

tb.columns = ['계급', '도수']
tb
# Out:
#       계급     도수
# 0   20.0  588.0
# 1   26.0  461.0
# 2   32.0  522.0
# 3   38.0  513.0
# 4   44.0  507.0
# 5   50.0  451.0
# 6   56.0  564.0
# 7   62.0  428.0
# 8   68.0  427.0
# 9   74.0  539.0
# 10  80.0    NaN

# %%
tb = tb.dropna()

# %%
# frequency
plt.figure(figsize=(14, 8))
plt.hist(df['age'], bins=30)
# Out:
# (array([184., 192., 212., 215., 100., 146., 177., 227., 118., 194., 158.,
#         161., 213., 160., 134., 101., 191., 159., 227., 154., 183., 210.,
#          79., 139., 171., 131., 125., 219., 106., 214.]),
#  array([20., 22., 24., 26., 28., 30., 32., 34., 36., 38., 40., 42., 44.,
#         46., 48., 50., 52., 54., 56., 58., 60., 62., 64., 66., 68., 70.,
#         72., 74., 76., 78., 80.]),
#  <a list of 30 Patch objects>)

# %%
# density
plt.figure(figsize=(14, 8))
plt.hist(df['age'], bins=30, density=True)
# Out:
# (array([0.0184, 0.0192, 0.0212, 0.0215, 0.01  , 0.0146, 0.0177, 0.0227,
#         0.0118, 0.0194, 0.0158, 0.0161, 0.0213, 0.016 , 0.0134, 0.0101,
#         0.0191, 0.0159, 0.0227, 0.0154, 0.0183, 0.021 , 0.0079, 0.0139,
#         0.0171, 0.0131, 0.0125, 0.0219, 0.0106, 0.0214]),
#  array([20., 22., 24., 26., 28., 30., 32., 34., 36., 38., 40., 42., 44.,
#         46., 48., 50., 52., 54., 56., 58., 60., 62., 64., 66., 68., 70.,
#         72., 74., 76., 78., 80.]),
#  <a list of 30 Patch objects>)

# %%
shirt = list(df[df['product_type'] == 'Shirt'].age)
jacket = list(df[df['product_type'] == 'Jacket'].age)

# %%
plt.figure(figsize=(14, 8))

plt.hist([shirt, jacket], 20, label=['shirt', 'jacket'])
plt.legend(loc='upper right')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize=(14, 8))

plt.hist(shirt, 20, alpha = 0.5, label='shirt')
plt.hist(jacket, 20, alpha = 0.5, label='jacket')
plt.legend(loc='upper right')

plt.show()
