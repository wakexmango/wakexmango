# %% [markdown]
# # 문자형

# %%
a = 'Hello'
b = 'World'
c = '3'

print(a, type(a))
print(b, type(b))
print(c, type(c))
# Out:
# Hello <class 'str'>
# World <class 'str'>
# 3 <class 'str'>

# %%
print(c * 4)
# Out:
# 3333

# %%
print(a * 4)
# Out:
# HelloHelloHelloHello

# %%
print(c + 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-a5ecf9c3a261> in <module>()
# ----> 1 print(c + 4)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(c + a)
# Out:
# 3Hello

# %%
a = 'Hello'
b = 'World'
c = '3'

print(a, type(a))
print(b, type(b))
print(c, type(c))
# Out:
# Hello <class 'str'>
# World <class 'str'>
# 3 <class 'str'>

# %%
print(a + b)
print(a, b)
print(a + ' ' + b)
print(a*2 + ' ' + b)
print('-' * 70)
# Out:
# HelloWorld
# Hello World
# Hello               World
# HelloHello World
# ----------------------------------------------------------------------
