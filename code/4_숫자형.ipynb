# %% [markdown]
# # 숫자형

# %%
num1 = 100
num2 = 100.5432

print(num1, type(num1))
print(num2, type(num2))
# Out:
# 100 <class 'int'>
# 100.5432 <class 'float'>

# %%
print(num1+10)
print(num1-10)
print(num1/10)
# Out:
# 110
# 90
# 10.0

# %%
print(num1)
# Out:
# 100

# %%
num1 = num1 + 10
print(num1)
# Out:
# 110

# %%
num1 = 100
num1 += 10
print(num1)
# Out:
# 110

# %%
print(num2)
print(round(num2))
print(round(num2, 1))
print(round(num2, 2))
# Out:
# 100.5432
# 101
# 100.5
# 100.54

# %%
print(int(num2))
# Out:
# 100

# %%
PI=3.14
print(PI)
# Out:
# 3.14
