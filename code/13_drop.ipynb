# %%
import pandas as pd

df = pd.DataFrame({
'SIZE': ['L', 'M', 'L', 'S', 'XS'],
'product_type': ['Jacket', 'Shirt', 'Jacket', 'Trousers', 'Shirt'],
'color': ['red', 'black', 'black', 'red', 'blue'],
'quantity': [5, 15, 10, 20, 15],
})

df
# Out:
#   SIZE product_type  color  quantity
# 0    L       Jacket    red         5
# 1    M        Shirt  black        15
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20
# 4   XS        Shirt   blue        15

# %%
df.drop(['color'], axis=1)
# Out:
#   SIZE product_type  quantity
# 0    L       Jacket         5
# 1    M        Shirt        15
# 2    L       Jacket        10
# 3    S     Trousers        20
# 4   XS        Shirt        15

# %%
df.drop(['color', 'quantity'], axis=1)
# Out:
#   SIZE product_type
# 0    L       Jacket
# 1    M        Shirt
# 2    L       Jacket
# 3    S     Trousers
# 4   XS        Shirt

# %%
df[['SIZE', 'product_type']]
# Out:
#   SIZE product_type
# 0    L       Jacket
# 1    M        Shirt
# 2    L       Jacket
# 3    S     Trousers
# 4   XS        Shirt

# %%
df
# Out:
#   SIZE product_type  color  quantity
# 0    L       Jacket    red         5
# 1    M        Shirt  black        15
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20
# 4   XS        Shirt   blue        15

# %%
df.drop([0], axis=0)
# Out:
#   SIZE product_type  color  quantity
# 1    M        Shirt  black        15
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20
# 4   XS        Shirt   blue        15

# %%
df.drop([0])
# Out:
#   SIZE product_type  color  quantity
# 1    M        Shirt  black        15
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20
# 4   XS        Shirt   blue        15

# %%
df = df.drop([1, 4])

# %%
df
# Out:
#   SIZE product_type  color  quantity
# 0    L       Jacket    red         5
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20

# %%
df
# Out:
#   SIZE product_type  color  quantity
# 0    L       Jacket    red         5
# 1    M        Shirt  black        15
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20
# 4   XS        Shirt   blue        15

# %%
df.duplicated(['product_type'], keep='first')
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df.duplicated(['product_type'], keep='last')
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df
# Out:
#   SIZE product_type  color  quantity
# 0    L       Jacket    red         5
# 1    M        Shirt  black        15
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20
# 4   XS        Shirt   blue        15

# %%
df.drop_duplicates(['product_type'], keep='first')
# Out:
#   SIZE product_type  color  quantity
# 0    L       Jacket    red         5
# 1    M        Shirt  black        15
# 3    S     Trousers    red        20

# %%
df
# Out:
#   SIZE product_type  color  quantity
# 0    L       Jacket    red         5
# 1    M        Shirt  black        15
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20
# 4   XS        Shirt   blue        15

# %%
df.duplicated(['product_type'], keep='last')
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
df.drop_duplicates(['product_type'], keep='last')
# Out:
#   SIZE product_type  color  quantity
# 2    L       Jacket  black        10
# 3    S     Trousers    red        20
# 4   XS        Shirt   blue        15
