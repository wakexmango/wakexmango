# %% [markdown]
# # read_excel
# * [데이터 다운로드 링크](https://www.kaggle.com/ruchi798/shopping-cart-database?select=sales.csv)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd

customer_df = pd.read_csv('/content/drive/MyDrive/data/customers.csv', sep=',')

# %%
customer_df.tail(10)
# Out:
#      customer_id        customer_name  ...              state    country
# 990          991     Cristina Jowling  ...           Tasmania  Australia
# 991          992  Meredith Stansfield  ...         Queensland  Australia
# 992          993      Orella Singyard  ...           Victoria  Australia
# 993          994        Vanna Densham  ...  Western Australia  Australia
# 994          995        Leandra Derks  ...  Western Australia  Australia
# 995          996       Elvira Sarfati  ...           Tasmania  Australia
# 996          997       Dickie Grushin  ...           Tasmania  Australia
# 997          998       Rebecka Fabler  ...         Queensland  Australia
# 998          999       Carita Vynarde  ...  Western Australia  Australia
# 999         1000     Mandel Fairbanks  ...           Tasmania  Australia
#
# [10 rows x 9 columns]

# %%
customer_df = pd.read_excel('/content/drive/MyDrive/data/customers.xlxs')

# %%
customer_df

# %%
customer_df.count()

# %%
customer_df.head(3)
