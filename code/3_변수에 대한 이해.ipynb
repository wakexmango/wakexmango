# %% [markdown]
# # 변수에 대한 이해

# %%
# 10 = num
num = 10
print(num)
# Out:
# 10

# %%
print(num, num*2, num**2, num/num)
# Out:
# 10 20 100 1.0

# %%
aaa = 3
print(aaa)
# Out:
# 3

# %%
aaa = 5
print(aaa)
# Out:
# 5

# %%
AAA = 3 
print(aaa, AAA)
# Out:
# 5 3

# %%
a a a = 1
# Out:
#   File "<ipython-input-8-e95eef12fcad>", line 1
#     a a a = 1
#       ^
# SyntaxError: invalid syntax

# %%
10a = 10
# Out:
#   File "<ipython-input-9-c4b960182618>", line 1
#     10a = 10
#       ^
# SyntaxError: invalid syntax

# %%
global = 100
# Out:
#   File "<ipython-input-10-c70969a739e2>", line 1
#     global = 100
#            ^
# SyntaxError: invalid syntax

# %%
global_data = 100
print(global_data)
# Out:
# 100
