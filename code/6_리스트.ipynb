# %% [markdown]
# # 리스트

# %%
list_ = []
print(list_, type(list_))
# Out:
# [] <class 'list'>

# %%
student = ['Susan', 'Jessica', 'John', 'Michael']
age = [19, 15, 16, 17]
print(student)
print(age)
# Out:
# ['Susan', 'Jessica', 'John', 'Michael']
# [19, 15, 16, 17]

# %%
print(student[1], age[1])
print(student[-1], age[-1])
# Out:
# Jessica 15
# Michael 17

# %%
print(student)
print(age)
print()

student[1] = 'Jennie'
age[1] = 18

print(student)
print(age)
# Out:
# ['Susan', 'Jessica', 'John', 'Michael']
# [19, 15, 16, 17]
#
# ['Susan', 'Jennie', 'John', 'Michael']
# [19, 18, 16, 17]

# %%
print(student[1:2])
print(student[1:3])
# Out:
# ['Jennie']
# ['Jennie', 'John']

# %%
student.reverse()
print(student)
# Out:
# ['Michael', 'John', 'Jennie', 'Susan']

# %%
student.append('mango')
print(student)
# Out:
# ['Michael', 'John', 'Jennie', 'Susan', 'mango']

# %%
student.remove('mango')
print(student)
# Out:
# ['Michael', 'John', 'Jennie', 'Susan']

# %%
# sorted
age.sort()
print(age)
age.sort(reverse=True)
print(age)
# Out:
# [16, 17, 18, 19]
# [19, 18, 17, 16]

# %%
# -1 이 안됨
print(age)
age.insert(0, 2)
print(age)
# Out:
# [19, 18, 17, 16]
# [2, 19, 18, 17, 16]

# %%
age.pop(0)
print(age)
# Out:
# [18, 17, 16]

# %%
stu_list = [student, age]
print(stu_list)
# Out:
# [['Michael', 'John', 'Jennie', 'Susan'], [18, 17, 16]]

# %%
stu_list[0]
# Out:
# ['Michael', 'John', 'Jennie', 'Susan']

# %%
stu_list[1][0]
# Out:
# 18
