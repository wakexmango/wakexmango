# %% [markdown]
# # read_excel
# * [데이터 다운로드 링크](https://www.kaggle.com/ruchi798/shopping-cart-database?select=sales.csv)

# %%
import pandas as pd

# %%
products_df = pd.read_csv('/content/drive/MyDrive/data/products.csv')
products_df.head()
# Out:
#    product_ID  ...                                   description
# 0           0  ...  A red coloured, XS sized, Oxford Cloth Shirt
# 1           1  ...   A red coloured, S sized, Oxford Cloth Shirt
# 2           2  ...   A red coloured, M sized, Oxford Cloth Shirt
# 3           3  ...   A red coloured, L sized, Oxford Cloth Shirt
# 4           4  ...  A red coloured, XL sized, Oxford Cloth Shirt
#
# [5 rows x 8 columns]

# %%
# NULL 값 체크
products_df.isnull().sum()
# Out:
# product_ID      0
# product_type    0
# product_name    0
# size            0
# colour          0
# price           0
# quantity        0
# description     0
# dtype: int64

# %%
# value 별로 몇 개의 데이터 있는지 확인
products_df['product_type'].value_counts()
# Out:
# Shirt       420
# Jacket      420
# Trousers    420
# Name: product_type, dtype: int64

# %%
products_df['size'].value_counts()
# Out:
# XS    252
# S     252
# M     252
# L     252
# XL    252
# Name: size, dtype: int64

# %%
products_df['colour'].value_counts()
# Out:
# red       180
# orange    180
# yellow    180
# green     180
# blue      180
# indigo    180
# violet    180
# Name: colour, dtype: int64

# %%
# 기초 통계
products_df['price'].describe()
# Out:
# count    1260.000000
# mean      105.805556
# std         9.704423
# min        90.000000
# 25%        95.750000
# 50%       108.500000
# 75%       114.000000
# max       119.000000
# Name: price, dtype: float64

# %%
products_df['quantity'].describe()
# Out:
# count    1260.000000
# mean       60.150000
# std        11.670573
# min        40.000000
# 25%        50.000000
# 50%        60.000000
# 75%        70.000000
# max        80.000000
# Name: quantity, dtype: float64

# %%
products_df.loc[products_df['quantity'] == 40]
# Out:
#       product_ID  ...                                        description
# 61            61  ...            A indigo coloured, S sized, Dress Shirt
# 209          209  ...   A violet coloured, XL sized, Camp Collared Shirt
# 221          221  ...         A yellow coloured, S sized, Chambray Shirt
# 245          245  ...               A red coloured, XS sized, Polo Shirt
# 414          414  ...  A indigo coloured, XL sized, Casual Slim Fit S...
# 489          489  ...         A violet coloured, XL sized, Puffer Jacket
# 493          493  ...        A red coloured, L sized, Windbreaker Jacket
# 551          551  ...         A indigo coloured, S sized, Leather Jacket
# 557          557  ...         A violet coloured, M sized, Leather Jacket
# 610          610  ...        A green coloured, XS sized, Cardigan Jacket
# 623          623  ...        A indigo coloured, L sized, Cardigan Jacket
# 625          625  ...       A violet coloured, XS sized, Cardigan Jacket
# ...

# %%
products_df['quantity'].min()
# Out:
# 40

# %%
products_df['quantity'].sum()
# Out:
# 75789

# %%
products_df['quantity'].max()
# Out:
# 80

# %%
products_df['quantity'].median()
# Out:
# 60.0

# %%
products_df['status'] = ''
products_df.head()
# Out:
#    product_ID product_type  ...                                   description status
# 0           0        Shirt  ...  A red coloured, XS sized, Oxford Cloth Shirt
# 1           1        Shirt  ...   A red coloured, S sized, Oxford Cloth Shirt
# 2           2        Shirt  ...   A red coloured, M sized, Oxford Cloth Shirt
# 3           3        Shirt  ...   A red coloured, L sized, Oxford Cloth Shirt
# 4           4        Shirt  ...  A red coloured, XL sized, Oxford Cloth Shirt
#
# [5 rows x 9 columns]

# %%
products_df.loc[(products_df['price'] >= 114), 'status'] = '비싸다'
products_df.head(5)
# Out:
#    product_ID product_type  ...                                   description status
# 0           0        Shirt  ...  A red coloured, XS sized, Oxford Cloth Shirt    비싸다
# 1           1        Shirt  ...   A red coloured, S sized, Oxford Cloth Shirt    비싸다
# 2           2        Shirt  ...   A red coloured, M sized, Oxford Cloth Shirt    비싸다
# 3           3        Shirt  ...   A red coloured, L sized, Oxford Cloth Shirt    비싸다
# 4           4        Shirt  ...  A red coloured, XL sized, Oxford Cloth Shirt    비싸다
#
# [5 rows x 9 columns]

# %%
products_df.loc[(products_df['price'] < 114), 'status'] = '보통이다.'
# Out:
#       product_ID  ... status
# 70            70  ...
# 71            71  ...
# 72            72  ...
# 73            73  ...
# 74            74  ...
# ...          ...  ...    ...
# 1255        1255  ...
# 1256        1256  ...
# 1257        1257  ...
# 1258        1258  ...
# 1259        1259  ...
#
# [910 rows x 9 columns]

# %%
products_df.loc[(products_df['price'] < 114), 'status'] = '보통이다'
products_df.tail(5)
# Out:
#       product_ID  ... status
# 1255        1255  ...   보통이다
# 1256        1256  ...   보통이다
# 1257        1257  ...   보통이다
# 1258        1258  ...   보통이다
# 1259        1259  ...   보통이다
#
# [5 rows x 9 columns]

# %%
products_df.groupby('status').size()
# Out:
# status
# 보통이다    910
# 비싸다     350
# dtype: int64

# %%
products_df[products_df['status'] == '비싸다']['price'].describe()
# Out:
# count    350.000000
# mean     116.600000
# std        1.962397
# min      114.000000
# 25%      115.000000
# 50%      116.500000
# 75%      119.000000
# max      119.000000
# Name: price, dtype: float64

# %% [markdown]
# # 문제 1.
# * size가 XL인 상품들의 기초 통계를 확인하고, 아래와 같이 label을 정의하세요.
#   * 75% 이상인 상품에는 '많음'
#   * 나머지 상품에는 '보통'

# %%
products_df.head()
# Out:
#    product_ID product_type  ...                                   description status
# 0           0        Shirt  ...  A red coloured, XS sized, Oxford Cloth Shirt    비싸다
# 1           1        Shirt  ...   A red coloured, S sized, Oxford Cloth Shirt    비싸다
# 2           2        Shirt  ...   A red coloured, M sized, Oxford Cloth Shirt    비싸다
# 3           3        Shirt  ...   A red coloured, L sized, Oxford Cloth Shirt    비싸다
# 4           4        Shirt  ...  A red coloured, XL sized, Oxford Cloth Shirt    비싸다
#
# [5 rows x 9 columns]

# %%
prd_xl_df = products_df[products_df['size'] == 'XL']
prd_xl_df
# Out:
#       product_ID  ... status
# 4              4  ...    비싸다
# 9              9  ...    비싸다
# 14            14  ...    비싸다
# 19            19  ...    비싸다
# 24            24  ...    비싸다
# ...          ...  ...    ...
# 1239        1239  ...   보통이다
# 1244        1244  ...   보통이다
# 1249        1249  ...   보통이다
# 1254        1254  ...   보통이다
# 1259        1259  ...   보통이다
#
# [252 rows x 9 columns]

# %%
set(list(prd_xl_df['size']))

# %%
set(list(prd_xl_df['size']))
# Out:
# {'XL'}

# %%
prd_xl_df['size'].unique()
# Out:
# array(['XL'], dtype=object)

# %%
prd_xl_df['quantity'].describe()
# Out:
# count    252.000000
# mean      59.801587
# std       11.783924
# min       40.000000
# 25%       50.000000
# 50%       59.000000
# 75%       69.000000
# max       80.000000
# Name: quantity, dtype: float64

# %%
prd_xl_df['quantity_status'] = ''
prd_xl_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#       product_ID product_type  ... status quantity_status
# 4              4        Shirt  ...    비싸다
# 9              9        Shirt  ...    비싸다
# 14            14        Shirt  ...    비싸다
# 19            19        Shirt  ...    비싸다
# 24            24        Shirt  ...    비싸다
# ...          ...          ...  ...    ...             ...
# 1239        1239     Trousers  ...   보통이다
# 1244        1244     Trousers  ...   보통이다
# 1249        1249     Trousers  ...   보통이다
# 1254        1254     Trousers  ...   보통이다
# 1259        1259     Trousers  ...   보통이다
#
# [252 rows x 10 columns]

# %%
prd_xl_df.loc[(prd_xl_df['quantity'] >= 69), 'quantity_status'] = '많음'
prd_xl_df.loc[(prd_xl_df['quantity'] < 69), 'quantity_status'] = '보통'

prd_xl_df
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#       product_ID product_type  ... status quantity_status
# 4              4        Shirt  ...    비싸다              보통
# 9              9        Shirt  ...    비싸다              보통
# 14            14        Shirt  ...    비싸다              보통
# 19            19        Shirt  ...    비싸다              보통
# 24            24        Shirt  ...    비싸다              보통
# ...          ...          ...  ...    ...             ...
# 1239        1239     Trousers  ...   보통이다              보통
# 1244        1244     Trousers  ...   보통이다              보통
# ...

# %%
prd_xl_df.groupby('quantity_status').size()
# Out:
# quantity_status
# 많음     66
# 보통    186
# dtype: int64
