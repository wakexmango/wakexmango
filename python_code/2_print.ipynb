# %% [markdown]
# # print

# %%
print(3)
# Out:
# 3

# %%
print(3*4)
# Out:
# 12

# %%
print('3')
# Out:
# 3

# %%
print('3'*10)
# Out:
# 3333333333

# %%
print('공부하자!')
# Out:
# 공부하자!

# %%
print("공부하자!")
# Out:
# 공부하자!

# %%
print('"공부"하자!')
# Out:
# "공부"하자!

# %%
print("'공부'하자!")
# Out:
# '공부'하자!
