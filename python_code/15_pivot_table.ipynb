# %% [markdown]
# # 피봇테이블

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
product_df = pd.read_csv('/content/drive/MyDrive/data/products.csv', sep=',')
product_df.head(5)
# Out:
#    product_ID  ...                                   description
# 0           0  ...  A red coloured, XS sized, Oxford Cloth Shirt
# 1           1  ...   A red coloured, S sized, Oxford Cloth Shirt
# 2           2  ...   A red coloured, M sized, Oxford Cloth Shirt
# 3           3  ...   A red coloured, L sized, Oxford Cloth Shirt
# 4           4  ...  A red coloured, XL sized, Oxford Cloth Shirt
#
# [5 rows x 8 columns]

# %%
pd.pivot_table(product_df, index='product_type', columns='size', values='quantity', aggfunc=sum)
# Out:
# size             L     M     S    XL    XS
# product_type
# Jacket        5141  4968  5012  5071  5195
# Shirt         5365  4977  4991  4976  4954
# Trousers      5084  4915  5029  5023  5088

# %%
import numpy as np 

pd.pivot_table(product_df, index='product_type', columns='size', values='quantity', aggfunc=np.sum)

# %%
agg_prd_df = pd.pivot_table(product_df, index='product_type', columns='size'
                                      , values='quantity', aggfunc=sum)
agg_prd_df
# Out:
# size             L     M     S    XL    XS
# product_type
# Jacket        5141  4968  5012  5071  5195
# Shirt         5365  4977  4991  4976  4954
# Trousers      5084  4915  5029  5023  5088

# %%
agg_prd_df = agg_prd_df.reset_index()
agg_prd_df
# Out:
# size product_type     L     M     S    XL    XS
# 0          Jacket  5141  4968  5012  5071  5195
# 1           Shirt  5365  4977  4991  4976  4954
# 2        Trousers  5084  4915  5029  5023  5088

# %%
agg_prd_df = agg_prd_df.set_index('product_type')
agg_prd_df
# Out:
# size             L     M     S    XL    XS
# product_type
# Jacket        5141  4968  5012  5071  5195
# Shirt         5365  4977  4991  4976  4954
# Trousers      5084  4915  5029  5023  5088

# %% [markdown]
# ### 문제1
# * product_type이 Shirt인 행의 모든 데이터를 출력하세요.

# %%
agg_prd_df.loc['Shirt']

# %%
agg_prd_df.iloc[1]

# %%
agg_prd_df.T['Shirt']

# %%
agg_prd_df.T['']

# %%
agg_prd_df

# %% [markdown]
# ### 문제2
# * Trousers의 'XL', 'L' 사이즈의 수량을 출력하세요.

# %%
agg_prd_df.loc['Trousers'][['XL','L']]

# %%
agg_prd_df[['XL','L']]['Trousers':'Trousers']

# %%
agg_prd_df[['XL','L']].T['Trousers']

# %%
agg_prd_df[['XL','L']].T

# %%
agg_prd_df

# %%
agg_prd_df.iloc[2:,][['XL', 'L']]

# %%
agg_prd_df.iloc[2:,][['XL', 'L']]
